# %%
# Loading all the required libraries
from pandas import Series
from matplotlib import pyplot
import numpy as np
# %matplotlib inline

# %%
data = Series.from_csv('AirPassengers.csv', header=0)
series.plot()
pyplot.show()
# Out:
# C:\Users\sinkur\AppData\Local\Continuum\anaconda3.1\envs\virtual_platform\lib\site-packages\pandas\core\series.py:2890: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   infer_datetime_format=infer_datetime_format)

# %%
X = data.values
partition =int(len(X) / 2)
X1, X2 = X[0:partition], X[partition:]
mean1, mean2 =np.nanmean(X1) ,np.nanmean(X2)
var1, var2 = np.nanvar(X1), np.nanvar(X2)
print('mean1=%f, mean2=%f' % (mean1, mean2))
print('variance1=%f, variance2=%f' % (var1, var2))
# Out:
# mean1=182.902778, mean2=377.694444
# variance1=2244.087770, variance2=7367.962191
