# %%
from random import gauss
from random import seed
from pandas import Series
from pandas.tools.plotting import autocorrelation_plot
from matplotlib import pyplot

# %%
#Setting up the white noise series for us to analyze.
seed(1000)
#creating white noise series
series = [gauss(0.0, 1.0) for i in range(500)]
series = Series(series)

# %%
# Let's take the summary or statistic of it
print(series.describe())
# Out:
# count    500.000000
# mean       0.026039
# std        1.050492
# min       -3.102231
# 25%       -0.622977
# 50%        0.047703
# 75%        0.694352
# max        3.192393
# dtype: float64

# %%
#line plot
series.plot()
pyplot.show()

# %%
#autocorrelation
autocorrelation_plot(series)
pyplot.show()
# Out:
# C:\Users\sinkur\AppData\Local\Continuum\anaconda3.1\envs\virtual_platform\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: 'pandas.tools.plotting.autocorrelation_plot' is deprecated, import 'pandas.plotting.autocorrelation_plot' instead.
